# %%
from src.api import heptatonic_scale_form
from src.constants import HEPTATONIC_ORDER_KEYS, MODAL_SERIES_KEYS

for scale in HEPTATONIC_ORDER_KEYS:
    print(scale)
    for mode in MODAL_SERIES_KEYS:
        data = heptatonic_scale_form(scale_name=scale, modal_name=mode)
        print(f"\t{mode:15}{data['interval_structure']}\t{data['interval_scale']}")
# Out:
# diatonic
# 	ionian         (0, 2, 4, 5, 7, 9, 11)	('1', '2', '3', '4', '5', '6', '7')
# 	dorian         (0, 2, 3, 5, 7, 9, 10)	('1', '2', 'b3', '4', '5', '6', 'b7')
# 	phrygian       (0, 1, 3, 5, 7, 8, 10)	('1', 'b2', 'b3', '4', '5', 'b6', 'b7')
# 	lydian         (0, 2, 4, 6, 7, 9, 11)	('1', '2', '3', '#4', '5', '6', '7')
# 	mixolydian     (0, 2, 4, 5, 7, 9, 10)	('1', '2', '3', '4', '5', '6', 'b7')
# 	aeolian        (0, 2, 3, 5, 7, 8, 10)	('1', '2', 'b3', '4', '5', 'b6', 'b7')
# 	locrian        (0, 1, 3, 5, 6, 8, 10)	('1', 'b2', 'b3', '4', 'b5', 'b6', 'b7')
# altered
# 	ionian         (0, 1, 3, 4, 6, 8, 10)	('1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7')
# 	dorian         (0, 2, 3, 5, 7, 9, 11)	('1', '2', 'b3', '4', '5', '6', '7')
# 	phrygian       (0, 1, 3, 5, 7, 9, 10)	('1', 'b2', 'b3', '4', '5', '6', 'b7')
# 	lydian         (0, 2, 4, 6, 8, 9, 11)	('1', '2', '3', '#4', '#5', '6', '7')
# 	mixolydian     (0, 2, 4, 6, 7, 9, 10)	('1', '2', '3', '#4', '5', '6', 'b7')
# ...
